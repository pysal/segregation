# %% [markdown]
# # Building a summary tables

# %%
import pickle
import pandas as pd
import os
os.chdir('/bigdata/reylab/renancortes/ridir_related/')

import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
# Load results
with open('res_data.pkl', 'rb') as input:
    x = pickle.load(input)

# To vary the approach it is needed to vary x[i]

# %%
# indexes 25
# approaches 2
# scenarios 4

# %%
scenario_1 = x[0:2]
scenario_2 = x[2:4]
scenario_3 = x[4:6]
scenario_4 = x[6:8]

# %%
name = []
approach = []
scenario = []
p_value = []

for i in range(23):
    
    aux = scenario_1[0][i][0]
    
    if (aux.est_sim.mean() > aux.est_point_diff):
        sign = "-"
    else:
        sign = "+"
        
    name.append(aux._class_name)
    approach.append("Random Data")
    scenario.append("1")
    p_value.append("{:.3f}".format(aux.p_value) + " " + sign)
    
data = pd.DataFrame({'name': name, 'approach': approach, 'scenario': scenario, 'p_value': p_value})


name = []
approach = []
scenario = []
p_value = []

for i in range(23):
    
    aux = scenario_1[1][i][0]
    
    if (aux.est_sim.mean() > aux.est_point_diff):
        sign = "-"
    else:
        sign = "+"
    
    name.append(aux._class_name)
    approach.append("Pseudo Cumulative")
    scenario.append("1")
    p_value.append("{:.3f}".format(aux.p_value) + " " + sign)

data = data.append(pd.DataFrame({'name': name, 'approach': approach, 'scenario': scenario, 'p_value': p_value}), ignore_index = True)




name = []
approach = []
scenario = []
p_value = []

for i in range(23):
    
    aux = scenario_2[0][i][0]
        
    if (aux.est_sim.mean() > aux.est_point_diff):
        sign = "-"
    else:
        sign = "+"
    
    name.append(aux._class_name)
    approach.append("Random Data")
    scenario.append("2")
    p_value.append("{:.3f}".format(aux.p_value) + " " + sign)
    
data = data.append(pd.DataFrame({'name': name, 'approach': approach, 'scenario': scenario, 'p_value': p_value}), ignore_index = True)


name = []
approach = []
scenario = []
p_value = []

for i in range(23):
    
    aux = scenario_2[1][i][0]
    
    name.append(aux._class_name)
    approach.append("Pseudo Cumulative")
    scenario.append("2")
    p_value.append("{:.3f}".format(aux.p_value) + " " + sign)

data = data.append(pd.DataFrame({'name': name, 'approach': approach, 'scenario': scenario, 'p_value': p_value}), ignore_index = True)




name = []
approach = []
scenario = []
p_value = []

for i in range(23):
    
    aux = scenario_3[0][i][0]
        
    if (aux.est_sim.mean() > aux.est_point_diff):
        sign = "-"
    else:
        sign = "+"
    
    name.append(aux._class_name)
    approach.append("Random Data")
    scenario.append("3")
    p_value.append("{:.3f}".format(aux.p_value) + " " + sign)
    
data = data.append(pd.DataFrame({'name': name, 'approach': approach, 'scenario': scenario, 'p_value': p_value}), ignore_index = True)


name = []
approach = []
scenario = []
p_value = []

for i in range(23):
    
    aux = scenario_3[1][i][0]
        
    if (aux.est_sim.mean() > aux.est_point_diff):
        sign = "-"
    else:
        sign = "+"
    
    name.append(aux._class_name)
    approach.append("Pseudo Cumulative")
    scenario.append("3")
    p_value.append("{:.3f}".format(aux.p_value) + " " + sign)

data = data.append(pd.DataFrame({'name': name, 'approach': approach, 'scenario': scenario, 'p_value': p_value}), ignore_index = True)




name = []
approach = []
scenario = []
p_value = []

for i in range(23):
    
    aux = scenario_4[0][i][0]
        
    if (aux.est_sim.mean() > aux.est_point_diff):
        sign = "-"
    else:
        sign = "+"
    
    name.append(aux._class_name)
    approach.append("Random Data")
    scenario.append("4")
    p_value.append("{:.3f}".format(aux.p_value) + " " + sign)
    
data = data.append(pd.DataFrame({'name': name, 'approach': approach, 'scenario': scenario, 'p_value': p_value}), ignore_index = True)


name = []
approach = []
scenario = []
p_value = []

for i in range(23):
    
    aux = scenario_4[1][i][0]
        
    if (aux.est_sim.mean() > aux.est_point_diff):
        sign = "-"
    else:
        sign = "+"
    
    name.append(aux._class_name)
    approach.append("Pseudo Cumulative")
    scenario.append("4")
    p_value.append("{:.3f}".format(aux.p_value) + " " + sign)

data = data.append(pd.DataFrame({'name': name, 'approach': approach, 'scenario': scenario, 'p_value': p_value}), ignore_index = True)

# %%
data.head()
# Out:
#       approach      name  p_value scenario
# 0  Random Data    Dissim  1.000 +        1
# 1  Random Data  Gini_Seg  1.000 +        1
# 2  Random Data   Entropy  1.000 +        1
# 3  Random Data  Atkinson  1.000 -        1
# 4  Random Data  Exposure  1.000 +        1

# %%
# For Concentration
scenario_1 = x[8:10]
scenario_2 = x[10:12]
scenario_3 = x[12:14]
scenario_4 = x[14:16]

# %%
name = []
approach = []
scenario = []
p_value = []

for i in range(2):
    
    aux = scenario_1[0][i][0]
    
    if (aux.est_sim.mean() > aux.est_point_diff):
        sign = "-"
    else:
        sign = "+"
        
    name.append(aux._class_name)
    approach.append("Random Data")
    scenario.append("1")
    p_value.append("{:.3f}".format(aux.p_value) + " " + sign)
    
data = data.append(pd.DataFrame({'name': name, 'approach': approach, 'scenario': scenario, 'p_value': p_value}), ignore_index = True)


name = []
approach = []
scenario = []
p_value = []

for i in range(2):
    
    aux = scenario_1[1][i][0]
        
    if (aux.est_sim.mean() > aux.est_point_diff):
        sign = "-"
    else:
        sign = "+"
    
    name.append(aux._class_name)
    approach.append("Pseudo Cumulative")
    scenario.append("1")
    p_value.append("{:.3f}".format(aux.p_value) + " " + sign)

data = data.append(pd.DataFrame({'name': name, 'approach': approach, 'scenario': scenario, 'p_value': p_value}), ignore_index = True)




name = []
approach = []
scenario = []
p_value = []

for i in range(2):
    
    aux = scenario_2[0][i][0]
        
    if (aux.est_sim.mean() > aux.est_point_diff):
        sign = "-"
    else:
        sign = "+"
    
    name.append(aux._class_name)
    approach.append("Random Data")
    scenario.append("2")
    p_value.append("{:.3f}".format(aux.p_value) + " " + sign)
    
data = data.append(pd.DataFrame({'name': name, 'approach': approach, 'scenario': scenario, 'p_value': p_value}), ignore_index = True)


name = []
approach = []
scenario = []
p_value = []

for i in range(2):
    
    aux = scenario_2[1][i][0]
        
    if (aux.est_sim.mean() > aux.est_point_diff):
        sign = "-"
    else:
        sign = "+"
    
    name.append(aux._class_name)
    approach.append("Pseudo Cumulative")
    scenario.append("2")
    p_value.append("{:.3f}".format(aux.p_value) + " " + sign)

data = data.append(pd.DataFrame({'name': name, 'approach': approach, 'scenario': scenario, 'p_value': p_value}), ignore_index = True)




name = []
approach = []
scenario = []
p_value = []

for i in range(2):
    
    aux = scenario_3[0][i][0]
        
    if (aux.est_sim.mean() > aux.est_point_diff):
        sign = "-"
    else:
        sign = "+"
    
    name.append(aux._class_name)
    approach.append("Random Data")
    scenario.append("3")
    p_value.append("{:.3f}".format(aux.p_value) + " " + sign)
    
data = data.append(pd.DataFrame({'name': name, 'approach': approach, 'scenario': scenario, 'p_value': p_value}), ignore_index = True)


name = []
approach = []
scenario = []
p_value = []

for i in range(2):
    
    aux = scenario_3[1][i][0]
        
    if (aux.est_sim.mean() > aux.est_point_diff):
        sign = "-"
    else:
        sign = "+"
    
    name.append(aux._class_name)
    approach.append("Pseudo Cumulative")
    scenario.append("3")
    p_value.append("{:.3f}".format(aux.p_value) + " " + sign)

data = data.append(pd.DataFrame({'name': name, 'approach': approach, 'scenario': scenario, 'p_value': p_value}), ignore_index = True)




name = []
approach = []
scenario = []
p_value = []

for i in range(2):
    
    aux = scenario_4[0][i][0]
        
    if (aux.est_sim.mean() > aux.est_point_diff):
        sign = "-"
    else:
        sign = "+"
    
    name.append(aux._class_name)
    approach.append("Random Data")
    scenario.append("4")
    p_value.append("{:.3f}".format(aux.p_value) + " " + sign)
    
data = data.append(pd.DataFrame({'name': name, 'approach': approach, 'scenario': scenario, 'p_value': p_value}), ignore_index = True)


name = []
approach = []
scenario = []
p_value = []

for i in range(2):
    
    aux = scenario_4[1][i][0]
        
    if (aux.est_sim.mean() > aux.est_point_diff):
        sign = "-"
    else:
        sign = "+"
    
    name.append(aux._class_name)
    approach.append("Pseudo Cumulative")
    scenario.append("4")
    p_value.append("{:.3f}".format(aux.p_value) + " " + sign)

data = data.append(pd.DataFrame({'name': name, 'approach': approach, 'scenario': scenario, 'p_value': p_value}), ignore_index = True)

# %%
# To pivot table with string in the values
data.pivot_table(index = 'name', columns = ['scenario', 'approach'], values = 'p_value', aggfunc = lambda x: ' '.join(x))
# Out:
# scenario                                            1              \
# approach                            Pseudo Cumulative Random Data
# name
# Absolute_Centralization                       1.000 -     1.000 +
# Absolute_Concentration                        1.000 +     1.000 -
# Atkinson                                      1.000 -     1.000 -
# Bias_Corrected_Dissim                         0.008 -     0.988 +
# Boundary_Spatial_Dissim                       1.000 -     1.000 +
# Con_Prof                                      1.000 +     1.000 +
# Correlation_R                                 1.000 +     1.000 +
# Delta                                         0.998 -     1.000 -
# Density_Corrected_Dissim                      0.278 +     0.474 +
# Dissim                                        0.992 -     1.000 +
# Entropy                                       1.000 +     1.000 +
# Exposure                                      1.000 -     1.000 +
# ...
