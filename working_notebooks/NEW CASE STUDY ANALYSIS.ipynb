# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import pickle
import os
os.chdir('C:/Users/renan/Desktop/NEW_CASE_STUDY_RESULTS')
#os.chdir('C:/Users/Windows 8.1/Desktop/NEW_CASE_STUDY_RESULTS')

import warnings
warnings.filterwarnings("ignore")

import numpy as np

# %%
with open('sys_application_result_notebook.pkl', 'rb') as input:
    sys = pickle.load(input)
    
with open('per_application_result_notebook.pkl', 'rb') as input:
    per = pickle.load(input)
    
with open('la_la_application_result_notebook.pkl', 'rb') as input:
    la_la = pickle.load(input)
    
with open('la_ny_application_result_notebook.pkl', 'rb') as input:
    la_ny = pickle.load(input)
    
    

# THE SPATIAL PROXIMITY AND RELATIVE CLUSTERING WERE RUN WITH THE NUMPYS WERE RESULTING IN UNUSUAL VALUES. I RERUN WITH THE PANDAS LIKE AND REPLACE THEM 

    
with open('sys_application_result_notebook_SP_RCL.pkl', 'rb') as input:
    sys_sub = pickle.load(input)
    
with open('per_application_result_notebook_SP_RCL.pkl', 'rb') as input:
    per_sub = pickle.load(input)
    
with open('la_la_application_result_notebook_SP_RCL.pkl', 'rb') as input:
    la_la_sub = pickle.load(input)
    
with open('la_ny_application_result_notebook_SP_RCL.pkl', 'rb') as input:
    la_ny_sub = pickle.load(input)
    
    
# THE MODIFIEDS Dct and Gct WERE RESULTING IN UNUSUAL VALUES BECAUSE OF THE MISPLACED CORE DATA. I RERUN WITH THE PANDAS LIKE AND REPLACE THEM 

    
with open('sys_application_result_notebook_Dct_Gct.pkl', 'rb') as input:
    sys_modifieds = pickle.load(input)
    
#with open('per_application_result_notebook_Dct_Gct.pkl', 'rb') as input:
#    per_modifieds = pickle.load(input)
    
with open('la_la_application_result_notebook_Dct_Gct.pkl', 'rb') as input:
    la_la_modifieds = pickle.load(input)
    
with open('la_ny_application_result_notebook_Dct_Gct.pkl', 'rb') as input:
    la_ny_modifieds = pickle.load(input)

# %%
# SP and RCL

sys[18] = sys_sub[0]
sys[19] = sys_sub[1]

per[6] = per_sub[0]
per[7] = per_sub[1]

la_la[18] = la_la_sub[0]
la_la[19] = la_la_sub[1]

la_ny[18] = la_ny_sub[0]
la_ny[19] = la_ny_sub[1]



# Modifieds

sys[8] = sys_modifieds[0]
sys[9] = sys_modifieds[1]


la_la[8] = la_la_modifieds[0]
la_la[9] = la_la_modifieds[1]

la_ny[8] = la_ny_modifieds[0]
la_ny[9] = la_ny_modifieds[1]

# %% [markdown]
# # Los Angeles Systematic

# %%
# Systematic Approach

# The iterator of the subplots is not zero index-based

fig = plt.figure(figsize=(30, 20))
fig.subplots_adjust(hspace = 0.35, wspace = 0.35) # hspace space between lines

for i in range(1, len(sys) + 1):
    
    aux = sys[i-1]
    
    ax = fig.add_subplot(5, 5, i)
    sns.distplot(aux.est_sim, 
                 color = 'darkblue', 
                 hist_kws={'edgecolor':'black'},
                 kde_kws={'linewidth': 2})
    plt.axvline(aux.statistic, color = 'red', linewidth = 2)
    plt.title('{} = {}'.format(aux._class_name, round(aux.statistic, 3)), fontweight = "bold", fontsize = 12)

# %% [markdown]
# # Los Angeles Permutation

# %%
2 * np.array([(aux.statistic < aux.est_sim).sum(), (aux.statistic > aux.est_sim).sum()]).min() / 500
# Out:
# 0.0

# %%
# Permutation Approach

# The iterator of the subplots is not zero index-based

fig = plt.figure(figsize=(30, 20))
fig.subplots_adjust(hspace = 0.35, wspace = 0.35) # hspace space between lines

for i in range(1, len(per) + 1):
    
    aux = per[i-1]
    
    ax = fig.add_subplot(5, 5, i)
    sns.distplot(aux.est_sim, 
                 color = 'darkblue', 
                 hist_kws={'edgecolor':'black'},
                 kde_kws={'linewidth': 2})
    plt.axvline(aux.statistic, color = 'red', linewidth = 2)
    plt.title('{} = {}'.format(aux._class_name, round(aux.statistic, 3)), fontweight = "bold", fontsize = 15)
    #plt.title('{} = {} {}'.format(aux._class_name, round(aux.statistic, 3), 2 * np.array([(aux.statistic < aux.est_sim).sum(), (aux.statistic > aux.est_sim).sum()]).min() / 500), fontweight = "bold", fontsize = 15)

# %% [markdown]
# # LA & LA Random Data

# %%
# Random Data Approach

# The iterator of the subplots is not zero index-based

fig = plt.figure(figsize=(30, 20))
fig.subplots_adjust(hspace = 0.35, wspace = 0.35) # hspace space between lines

for i in range(1, len(la_la) + 1):
    
    aux = la_la[i-1]
    
    ax = fig.add_subplot(5, 5, i)
    sns.distplot(aux.est_sim, 
                 color = 'darkblue', 
                 hist_kws={'edgecolor':'black'},
                 kde_kws={'linewidth': 2})
    plt.axvline(aux.est_point_diff, color = 'red', linewidth = 2)
    plt.title('{} = {}'.format(aux._class_name, round(aux.est_point_diff, 3)), fontweight = "bold", fontsize = 15)
    #plt.title('{} = {} {}'.format(aux._class_name, round(aux.est_point_diff, 3), 2 * np.array([(aux.est_point_diff < aux.est_sim).sum(), (aux.est_point_diff > aux.est_sim).sum()]).min() / 500), fontweight = "bold", fontsize = 15)

# %% [markdown]
# # LA & NY Random Data

# %%
# Random Data Approach

# The iterator of the subplots is not zero index-based

fig = plt.figure(figsize=(30, 20))
fig.subplots_adjust(hspace = 0.35, wspace = 0.35) # hspace space between lines

for i in range(1, len(la_ny) + 1):
    
    aux = la_ny[i-1]
    
    ax = fig.add_subplot(5, 5, i)
    sns.distplot(aux.est_sim, 
                 color = 'darkblue', 
                 hist_kws={'edgecolor':'black'},
                 kde_kws={'linewidth': 2})
    plt.axvline(aux.est_point_diff, color = 'red', linewidth = 2)
    plt.title('{} = {}'.format(aux._class_name, round(aux.est_point_diff, 3)), fontweight = "bold", fontsize = 15)
    #plt.title('{} = {} {}'.format(aux._class_name, round(aux.est_point_diff, 3), 2 * np.array([(aux.est_point_diff < aux.est_sim).sum(), (aux.est_point_diff > aux.est_sim).sum()]).min() / 500), fontweight = "bold", fontsize = 15)

# %%
la_ny[18].est_sim.max()
# Out:
# 0.00020361189803508317

# %%
la_ny[20].est_sim
# Out:
# array([0.11320293, 0.08264639, 0.10600562, 0.0958889 , 0.09628603,
#        0.10140385, 0.09616332, 0.10423882, 0.09331163, 0.09339401,
#        0.09102213, 0.11121975, 0.0948312 , 0.1055173 , 0.09530015,
#        0.09643411, 0.09877631, 0.09174976, 0.09379792, 0.09929124,
#        0.10035189, 0.10842623, 0.08119065, 0.13101073, 0.09854369,
#        0.10100875, 0.08234765, 0.09354059, 0.10016381, 0.0854821 ,
#        0.10199606, 0.09380477, 0.11411147, 0.10738944, 0.10144019,
#        0.10070825, 0.11707324, 0.09008287, 0.09926858, 0.09593499,
#        0.10078914, 0.10686778, 0.10945379, 0.09149784, 0.0959903 ,
#        0.09967268, 0.10430839, 0.10504903, 0.10044491, 0.09131385,
#        0.10625268, 0.12451519, 0.1148766 , 0.10703503, 0.10136563,
#        0.11181838, 0.10347364, 0.09904781, 0.11183894, 0.09631643,
#        0.09094821, 0.09747041, 0.10461549, 0.097671  , 0.10896299,
#        0.08496601, 0.08525335, 0.10289264, 0.09663461, 0.11692035,
# ...

# %%
la_ny[20].est_point_diff
# Out:
# 0.07587763436169492

# %%
iterations = len(la_ny[20].est_sim)

# %%
aux1 = (la_ny[20].est_point_diff < la_ny[20].est_sim).sum()

# %%
aux2 = (la_ny[20].est_point_diff > la_ny[20].est_sim).sum()

# %%
p_value = 2 * np.array([aux1, aux2]).min() / iterations

# %%
p_value
# Out:
# 0.004

# %%
import numpy as np

# %%
p_value = (sum(est_sim > abs(point_estimation)) + sum(est_sim < -abs(point_estimation))) / iterations
