# %%
from osnap.data import read_ltdb

# if the archives were in my downloads folder, the paths might be something like this

sample = "C:\\Users\\renan\\Desktop\\osnap_data\\LTDB_Std_All_Sample.zip"
full = "C:\\Users\\renan\\Desktop\\osnap_data\\LTDB_Std_All_fullcount.zip"

df = read_ltdb(sample=sample, fullcount=full)
#df = df[['year','n_nonhisp_black_persons', 'n_total_pop']]

# %%
df.columns.tolist()
# Out:
# ['n_asian_under_15',
#  'n_black_under_15',
#  'n_hispanic_under_15',
#  'n_native_under_15',
#  'n_white_under_15',
#  'n_persons_under_18',
#  'n_asian_over_60',
#  'n_black_over_60',
#  'n_hispanic_over_60',
#  'n_native_over_60',
#  'n_persons_over_60',
#  'n_white_over_60',
#  'n_asian_over_65',
#  'n_black_over_65',
#  'n_hispanic_over_65',
#  'n_native_over_65',
#  'n_white_over_65',
#  'n_persons_over_75',
#  'n_persons_over_15',
#  'n_civilians_over_16',
#  'n_civilians_over_18',
#  'n_persons_over_25',
#  'n_age_5_older',
#  'n_asian_age_distribution',
#  'n_black_age_distribution',
#  'n_hispanic_age_distribution',
#  'n_native_age_distribution',
#  'n_white_age_distribution',
#  'n_asian_persons',
#  'n_black_persons',
#  'n_chinese_persons',
#  'n_labor_force',
#  'n_civilians_16_64',
#  'n_edu_college_greater',
#  'n_cuban_pop',
#  'n_poverty_determined_asian',
#  'n_poverty_determined_black',
#  'n_total_pop_sample',
#  'n_female_over_16',
# ...

# %%
df.head()
# Out:
#              year  n_nonhisp_black_persons  n_total_pop
# geoid
# 01001020500  1970                      NaN          9.0
# 01003010100  1970                      NaN       3470.0
# 01003010200  1970                      NaN       1881.0
# 01003010300  1970                      NaN       3724.0
# 01003010400  1970                      NaN       2600.0

# %%
df['geoid'] = df.index
df['state'] = df['geoid'].str[0:2]
df['county'] = df['geoid'].str[2:5]
df.head()
# Out:
#              year  n_nonhisp_black_persons  n_total_pop        geoid state  \
# geoid
# 01001020500  1970                      NaN          9.0  01001020500    01
# 01003010100  1970                      NaN       3470.0  01003010100    01
# 01003010200  1970                      NaN       1881.0  01003010200    01
# 01003010300  1970                      NaN       3724.0  01003010300    01
# 01003010400  1970                      NaN       2600.0  01003010400    01
#
#             county
# geoid
# 01001020500    001
# 01003010100    003
# 01003010200    003
# 01003010300    003
# 01003010400    003

# %%
max(df_riv[df_riv['year'] == 2010]['n_total_pop'])
# Out:
# 15424.0

# %%
# Filtering Riverside County
df_riv = df[(df['state'] == '06') & (df['county'] == '065')]

df_riv[df_riv['year'] == 2010]['n_total_pop'].sum()
# Out:
# 2192982.0

# %%
df_riv[df_riv['year'] == 2010]['n_nonhisp_black_persons'].sum()
# Out:
# 129961.0

# %%
#df_grouped = df.groupby(['county', 'county'], as_index = False).agg({"n_nonhisp_black_persons": "sum", "n_total_pop": "sum"})
#df_grouped.head()
# Out:
#   county tract  n_nonhisp_black_persons  n_total_pop
# 0    001   001                3667585.0   29215346.0
# 1    003   003                2846279.0   37738648.0
# 2    005   005                2896955.0   26312790.0
# 3    006   006                    541.0      76682.0
# 4    007   007                 842567.0   13443336.0

# %%
df_riv[df_riv['year'] == 2010].sort_values('n_total_pop')
# Out:
#              year  n_nonhisp_black_persons  n_total_pop        geoid state  \
# geoid
# 06065980004  2010                      0.0          0.0  06065980004    06
# 06065940100  2010                      0.0        136.0  06065940100    06
# 06065044521  2010                      0.0        707.0  06065044521    06
# 06065043814  2010                      0.0        726.0  06065043814    06
# 06065045116  2010                      0.0        996.0  06065045116    06
# 06065044405  2010                     15.0       1104.0  06065044405    06
# 06065044404  2010                      0.0       1177.0  06065044404    06
# 06065030101  2010                     11.0       1186.0  06065030101    06
# 06065045122  2010                      6.0       1237.0  06065045122    06
# 06065044807  2010                     40.0       1341.0  06065044807    06
# 06065044520  2010                     32.0       1442.0  06065044520    06
# ...

# %%
osnap.data.Dataset(name='Baltimore', source='ltdb', states='24', counties = ['005', '510'])

# %%
import pandas as pd
import numpy as np
from scipy.stats import norm

import os

os.chdir('C:/Users/renan/Desktop/inequality-segregation-supplementary-files/')

def calculate_dissim(data, group_pop_var, total_pop_var, b = 0.5, m = 1000):
    data = data.rename(columns={group_pop_var: 'group_pop_var', total_pop_var: 'total_pop_var'})
    T = data.total_pop_var.sum()
    P = data.group_pop_var.sum() / T
    data = data.assign(xi = data.group_pop_var,
                       yi = data.total_pop_var - data.group_pop_var,
                       ti = data.total_pop_var,
                       pi = np.where(data.total_pop_var == 0, 0, data.group_pop_var/data.total_pop_var))
    D = (((data.total_pop_var * abs(data.pi - P)))/ (2 * T * P * (1 - P))).sum()
    return D

# %%
census_2010 = pd.read_csv('data/std_2010_fullcount.csv', encoding = "ISO-8859-1", sep = ",")
df = census_2010.loc[census_2010.county == "Riverside County"][['trtid10','tract','pop10','nhblk10']]
df['other_group_pop'] = df.pop10 - df.nhblk10

census_2010.loc[census_2010.county == "Riverside County"].pop10.sum()
# Out:
# 2189641

# %%
census_2010.loc[census_2010.county == "Riverside County"].nhblk10.sum()
# Out:
# 148460

# %%
census_2010.loc[census_2010.county == "Riverside County"].sort_values('pop10')
# Out:
#           trtid10 state            county                 tract  pop10  \
# 6073   6065980004    CA  Riverside County  Census Tract 9800.04      9
# 12813  6065940100    CA  Riverside County     Census Tract 9401    166
# 6027   6065043814    CA  Riverside County   Census Tract 438.14    905
# 12595  6065044521    CA  Riverside County   Census Tract 445.21   1196
# 12341  6065030101    CA  Riverside County   Census Tract 301.01   1226
# 12617  6065044807    CA  Riverside County   Census Tract 448.07   1281
# 12685  6065045122    CA  Riverside County   Census Tract 451.22   1427
# 12673  6065045116    CA  Riverside County   Census Tract 451.16   1492
# 12689  6065045124    CA  Riverside County   Census Tract 451.24   1505
# 12709  6065045222    CA  Riverside County   Census Tract 452.22   1595
# 12613  6065044805    CA  Riverside County   Census Tract 448.05   1701
# 12593  6065044520    CA  Riverside County   Census Tract 445.20   1704
# ...

# %%
max(census_2010.loc[census_2010.county == "Riverside County"].pop10)
# Out:
# 14898

# %%
import libpysal as lps
# ?lps.weights.ContiguityWeightsLists
